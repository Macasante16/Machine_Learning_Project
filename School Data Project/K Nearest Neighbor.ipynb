# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os

stu_data = pd.read_csv('combined_csv.csv')
stu_data.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0     male        group B                some college  free/reduced
# 1     male        group D           bachelor's degree      standard
# 2     male        group A            some high school      standard
# 3     male        group C           bachelor's degree  free/reduced
# 4   female        group B          associate's degree  free/reduced
# 5   female        group E          associate's degree      standard
# 6   female        group A                 high school      standard
# 7   female        group C          associate's degree  free/reduced
# 8     male        group C                some college      standard
# 9     male        group D                 high school      standard
# 10    male        group B          associate's degree  free/reduced
# 11    male        group C          associate's degree  free/reduced
# 12  female        group C            some high school      standard
# ...

# %%
stu_data = stu_data.drop(columns=['race/ethnicity'])
